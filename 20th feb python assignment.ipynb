# %% [markdown]
# # Q1

# %% [markdown]
# # GET
#  when sending data, the GET method adds the data to the URL.
# # POST
# when sending data, the POST method send the data internelly and didn't add it to the URL.

# %% [markdown]
# # Q2

# %% [markdown]
# request is used in flask for contains all the data and send from the client to server.

# %% [markdown]
# # Q3

# %% [markdown]
# A redirect is used in the Flask class to send the user to a particular URL with the status code.

# %% [markdown]
# # Q4

# %% [markdown]
# # templates
# Templates are files that contain static data as well as placeholders for dynamic data.
# # render template()
# render_template is used to generate output from a template file that is found in the application's templates folder.

# %% [markdown]
# # Q5

# %%
from flask import Flask , request,jsonify
app = Flask(__name__)
@app.route('/postman_action',methods=['POST'])
def max_number():
    try:
        if (request.method=='POST'):
            num1 = request.json["num1"]
            num2 = request.json["num2"]
            if num1 > num2 :
                r = num1
                result = f"The maximum number is: {str(r)}"
            elif num1 < num2:
                r = num2
                result = f"The maximum number is: {str(r)}"
            elif num1 == num2:
                r = num1
                result=f"Both number is same"
            return jsonify(result)
    except Exception as e:
        return jsonify(e)
if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:bd20e1c8-0011-4b22-af21-76aaab3bab44.png)
