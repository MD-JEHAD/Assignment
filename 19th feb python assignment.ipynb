# %% [markdown]
# # Q1

# %% [markdown]
# Flask is a web framework. This means flask provides you with tools, libraries and technologies that allow you to build a web application.
# # advantage
# Scalable.
# Flexible.
# Easy to negotiate.
# Lightweight.
# Documentation.
# Not a lot of tools.

# %% [markdown]
# # Q2

# %%
from flask import Flask
app = Flask(__name__)
@app.route("/")
def hello_world():
    return "Helo World!!"
if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:85328d1e-4106-4aa3-9983-717727630ec1.png)

# %% [markdown]
# # Q3

# %% [markdown]
# App routing is the technique used to map the specific URL with the associated function intended to perform some task.
#
# It is useful to access the desired page directly without having to navigate from the home page.

# %% [markdown]
# # Q4

# %%
from flask import Flask
app = Flask(__name__)
@app.route("/welcome")
def welcome():
    return "Welcome to ABC Corporation"
@app.route("/")
def details():
    return """Company Name: ABC Corporation ,
              Location: India ,
              Contact Detail: 999-999-9999"""
if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:6a07f29f-ee42-42ad-bbfc-92339f2fc5e4.png)

# %% [markdown]
# ![image.png](attachment:7fdf8d84-740a-419a-885d-3876012b62e7.png)

# %% [markdown]
# # Q5

# %% [markdown]
# the url_for() function is used in Flask for URL Building.
